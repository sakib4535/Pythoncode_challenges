# %%
import pandas as pd

# %%
product_details = {'Ginger': 200, 'Flower': 100, 'Sauce': 5, 'Fish': 400, 'Choco': 567.3}
print(product_details)
type(product_details)
# Out:
# {'Ginger': 200, 'Flower': 100, 'Sauce': 5, 'Fish': 400, 'Choco': 567.3}
# dict

# %%
product_details_1 = pd.Series(product_details)
product_details_1.index
print(product_details_1)
# Out:
# Ginger    200.0
# Flower    100.0
# Sauce       5.0
# Fish      400.0
# Choco     567.3
# dtype: float64

# %%
Series_A = pd.Series([10, 20, 30, 40, 50, 12, 23, 45, 55, 78])
print(Series_A)
print(Series_A.index)
print(list(Series_A))
print(Series_A.dtype)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    12
# 6    23
# 7    45
# 8    55
# 9    78
# dtype: int64
# RangeIndex(start=0, stop=10, step=1)
# [10, 20, 30, 40, 50, 12, 23, 45, 55, 78]
# int64

# %%
for Series_A in range(5):
    for i in range(5):
        print(Series_A, i)
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 0 4
# 1 0
# 1 1
# 1 2
# 1 3
# 1 4
# 2 0
# 2 1
# 2 2
# 2 3
# 2 4
# 3 0
# 3 1
# 3 2
# 3 3
# 3 4
# 4 0
# 4 1
# 4 2
# 4 3
# 4 4

# %%
product_details_1[0]
# Out:
# 200.0

# %%
cp = {"HORECA": 50.5,
      "B2B": 14.3,
      "C2C": 18.8,
      "Direct": 67,
      "B2C": 44,
      "P2P": 45,
     }
print(cp)

cp_series = pd.Series(cp)
cp_series.index
print(cp_series)
cp_series["P2P"] = 40
print(cp_series)
# Out:
# {'HORECA': 50.5, 'B2B': 14.3, 'C2C': 18.8, 'Direct': 67, 'B2C': 44, 'P2P': 45}
# HORECA    50.5
# B2B       14.3
# C2C       18.8
# Direct    67.0
# B2C       44.0
# P2P       45.0
# dtype: float64
# HORECA    50.5
# B2B       14.3
# C2C       18.8
# Direct    67.0
# B2C       44.0
# P2P       40.0
# dtype: float64

# %%
index = pd.Series(product_details_1.index)
print(index)
index[4][4] #select 'Choco' and indiced 4th index position.
# Out:
# 0    Ginger
# 1    Flower
# 2     Sauce
# 3      Fish
# 4     Choco
# dtype: object
# 'o'

# %%
gpu_sets = {"GPU":["Radeon 6900 XT", 
                   "Radeon 6800 XT", 
                   "Radeon 6800", 
                   "Radeon 6700 XT", 
                   "Radeon 6600 XT", 
                   "Radeon 6600", 
                   "Radeon 6500 XT"],
           "Price":[1000, 650, 580, 480, 380, 330, 200],
           }
gpu_data = pd.DataFrame(gpu_sets, index = ['A', 'B', 'C', 'D', 'E', 'F', 'G'])
print(gpu_data)

categories = ['advance', 'advance', 'advance', 'mid range', 'mid range', 'low', 'low']
gpu_data_final = pd.DataFrame(gpu_sets, index = categories)
gpu_data_final
# Out:
#               GPU  Price
# A  Radeon 6900 XT   1000
# B  Radeon 6800 XT    650
# C     Radeon 6800    580
# D  Radeon 6700 XT    480
# E  Radeon 6600 XT    380
# F     Radeon 6600    330
# G  Radeon 6500 XT    200
#                       GPU  Price
# advance    Radeon 6900 XT   1000
# advance    Radeon 6800 XT    650
# advance       Radeon 6800    580
# mid range  Radeon 6700 XT    480
# mid range  Radeon 6600 XT    380
# low           Radeon 6600    330
# low        Radeon 6500 XT    200

# %%
#Data Frame - List of Dictionary

data = [{'Product Name':'GEFORCE RTX™ 3090', 'Price': 1499},
        {'Product Name':'GEFORCE RTX™ 3080', 'Price': 699},
        {'Product Name':'GEFORCE RTX™ 3070 Ti', 'Price': 599},
        {'Product Name':'GEFORCE RTX™ 3070', 'Price': 499},
        {'Product Name':'GEFORCE RTX™ 3060 Ti', 'Price': 399},
        {'Product Name':'GEFORCE RTX™ 3060', 'Price':329},
        {'Product Name':'GEFORCE RTX™ 3050', 'Price': 249}]

cagtegories = ['Advance', 'Advance']
data_df = pd.DataFrame(data)
data_df
# Out:
#            Product Name  Price
# 0     GEFORCE RTX™ 3090   1499
# 1     GEFORCE RTX™ 3080    699
# 2  GEFORCE RTX™ 3070 Ti    599
# 3     GEFORCE RTX™ 3070    499
# 4  GEFORCE RTX™ 3060 Ti    399
# 5     GEFORCE RTX™ 3060    329
# 6     GEFORCE RTX™ 3050    249

# %% [markdown]
# ## DataFrame - a dictionary of pandas series
#
# board = pd.Series(["MSI MAG Z490 Tomahawk", "MSI PRO Z690-A", "MSI Z490-A PRO ProSeries",  ])
# price = pd.Series([229, 239, ])

# %%
## DataFrame - a dictionary of pandas series

board = pd.Series(["MSI MAG Z490 Tomahawk", "MSI PRO Z690-A", "MSI Z490-A PRO ProSeries", "MSI MPG Z490 GAMING EDGE"])
price = pd.Series([229, 239, 209, 149])

board_data = {'Product Name': board, 'Product Price': price}
set_data = pd.DataFrame(board_data)
set_data
# Out:
#                Product Name  Product Price
# 0     MSI MAG Z490 Tomahawk            229
# 1            MSI PRO Z690-A            239
# 2  MSI Z490-A PRO ProSeries            209
# 3  MSI MPG Z490 GAMING EDGE            149

# %%
#DataFrame - From a list of lists

sets = [['Item A', 20], ['Item B', 60], ['Item C', 50]]
df = pd.DataFrame(sets)
df.columns = ['Product Name', 'Product quantity']
df
# Out:
#   Product Name  Product quantity
# 0       Item A                20
# 1       Item B                60
# 2       Item C                50

# %%
#Professional Way

data_set = pd.DataFrame(data = [['Product A', 2290], ['Product B', 2414], ['Product C', 2664]],
                       columns = ['Products', 'Product Price'],
                       index = ['A', 'B', 'C'])
data_set
# Out:
#     Products  Product Price
# A  Product A           2290
# B  Product B           2414
# C  Product C           2664

# %%
print(data_set.size)
print(data_set.shape)
print(data_set.dtypes)
# Out:
# 6
# (3, 2)
# Products         object
# Product Price     int64
# dtype: object

# %%
game = pd.read_csv("video_game_film.csv")
game
game.head(11)
# Out:
#                                            Title Release_date  \
# 0                              Super Mario Bros.    5/28/1993
# 1                                 Street Fighter   12/23/1994
# 2                                  Mortal Kombat    8/18/1995
# 3                    Mortal Kombat: Annihilation   11/21/1997
# 4                                 Wing Commander    3/12/1999
# 5                        Lara Croft: Tomb Raider    6/15/2001
# 6                                  Resident Evil    3/15/2002
# 7   Lara Croft: Tomb Raider – The Cradle of Life    7/25/2003
# 8                              House of the Dead   10/10/2003
# 9                      Resident Evil: Apocalypse    9/10/2004
# 10                             Alone in the Dark    1/28/2005
#
#     Worldwide_box_office  Rotten_tomatoes  Metacritic  \
# 0               38912465               24          35
# 1               99423521               13          34
# 2              124741822               44          60
# ...

# %%
game.iloc[0:3]
# Out:
#                Title Release_date  Worldwide_box_office  Rotten_tomatoes  \
# 0  Super Mario Bros.    5/28/1993              38912465               24
# 1     Street Fighter   12/23/1994              99423521               13
# 2      Mortal Kombat    8/18/1995             124741822               44
#
#    Metacritic                        Distributor Original game publisher
# 0          35  Buena Vista Pictures Distribution                Nintendo
# 1          34                 Universal Pictures                  Capcom
# 2          60                    New Line Cinema                  Midway

# %%
game.index[5:20]
# Out:
# RangeIndex(start=5, stop=20, step=1)

# %%
print(game.describe())
game_sort = sorted(game['Worldwide_box_office'])

for i in enumerate(game_sort):
    print(i)
# Out:
#        Worldwide_box_office  Rotten_tomatoes  Metacritic
# count          3.800000e+01        38.000000   38.000000
# mean           1.410857e+08        26.789474   35.026316
# std            1.348027e+08        19.986695   13.443549
# min            1.467410e+05         1.000000    9.000000
# 25%            3.360589e+07        10.750000   28.750000
# 50%            9.851549e+07        23.500000   35.000000
# 75%            2.404201e+08        36.750000   44.000000
# max            4.390489e+08        85.000000   66.000000
# (0, 146741)
# (1, 937490)
# (2, 3650275)
# (3, 7516532)
# (4, 10442808)
# (5, 11578059)
# (6, 12764201)
# (7, 13097915)
# (8, 13818181)
# (9, 31837037)
# (10, 38912465)
# (11, 42145959)
# (12, 51376861)
# (13, 52302796)
# (14, 55987321)
# (15, 82347656)
# (16, 83601013)
# (17, 85416905)
# (18, 97607453)
# (19, 99423521)
# (20, 101276318)
# (21, 102984862)
# (22, 124741822)
# (23, 129342769)
# (24, 148412065)
# (25, 156505388)
# (26, 203277636)
# (27, 240004424)
# ...

# %%
display(game)
# Out:
#                                             Title Release_date  \
# 0                               Super Mario Bros.    5/28/1993
# 1                                  Street Fighter   12/23/1994
# 2                                   Mortal Kombat    8/18/1995
# 3                     Mortal Kombat: Annihilation   11/21/1997
# 4                                  Wing Commander    3/12/1999
# 5                         Lara Croft: Tomb Raider    6/15/2001
# 6                                   Resident Evil    3/15/2002
# 7    Lara Croft: Tomb Raider – The Cradle of Life    7/25/2003
# 8                               House of the Dead   10/10/2003
# 9                       Resident Evil: Apocalypse    9/10/2004
# 10                              Alone in the Dark    1/28/2005
# 11                                           Doom   10/21/2005
# 12                                     BloodRayne     1/6/2006
# 13                                    Silent Hill    4/21/2006
# ...

# %%
game1 = game[game.Title == "Street Fighter"]
game1
# Out:
#             Title Release_date  Worldwide_box_office  Rotten_tomatoes  \
# 1  Street Fighter   12/23/1994              99423521               13
#
#    Metacritic         Distributor Original game publisher
# 1          34  Universal Pictures                  Capcom

# %%
import matplotlib.pyplot as plt

plt.plot(game.Metacritic, c="r", alpha=1)

# %%
import matplotlib.pyplot as plt

plt.plot(game.Metacritic, c="r", alpha=1)
plt.plot(game.Rotten_tomatoes, alpha=1)
plt.xlabel("Meta")
plt.ylabel("Rotten")
plt.legend(["Metacritic", "Rotten Tomatoes"])

# %%
game["Worldwide_box_office"].rolling(30).mean().plot()
plt.show()
game.sort_index(inplace=True)
game
# Out:
#                                                       Title  \
# Release_date
# 1993-05-28                                Super Mario Bros.
# 1994-12-23                                   Street Fighter
# 1995-08-18                                    Mortal Kombat
# 1997-11-21                      Mortal Kombat: Annihilation
# 1999-03-12                                   Wing Commander
# 2001-06-15                          Lara Croft: Tomb Raider
# 2002-03-15                                    Resident Evil
# 2003-07-25     Lara Croft: Tomb Raider – The Cradle of Life
# 2003-10-10                                House of the Dead
# 2004-09-10                        Resident Evil: Apocalypse
# 2005-01-28                                Alone in the Dark
# 2005-10-21                                             Doom
# 2006-01-06                                       BloodRayne
# 2006-04-21                                      Silent Hill
# ...

# %%
plt.hist(game["Worldwide_box_office"], bins=50, density=True, label="Data Histogram")
plt.xlabel("Numbers")
plt.ylabel("Box Office Return")
plt.legend();

# %%
import numpy as np

# %%
plt.hist(game["Worldwide_box_office"], label="Data")
plt.axvline(np.mean(game["Worldwide_box_office"]), ls="--", c="r", label="Mean Data")
plt.axvline(np.median(game["Worldwide_box_office"]), ls=":", label="Median Data")
plt.legend()
